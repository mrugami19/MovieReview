# %%
############ Compulsory Standard Library #################
import glob
import numpy as np
import matplotlib.pyplot as plt
import csv
import nltk
import re
import graphviz
from anytree import Node, RenderTree
from textblob import TextBlob

############ Sklearn pre-processing Library #################
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, ShuffleSplit
from sklearn.metrics import accuracy_score

############ Sklearn model Library #################
from sklearn.linear_model import LogisticRegression

# %%
def load_imdb(path, shuffle=True, random_state=42):
    
    print("Loading the imdb data")
    
    train_neg_files = glob.glob(path+"/train/neg/*.txt")
    train_pos_files = glob.glob(path+"/train/pos/*.txt")
    
    X_train_corpus = []
    y_train = []
    
    for tnf in train_neg_files:
        f = open(tnf, 'r', encoding="utf8")
        line = f.read()
        #line = line[:len(line)/2]
        X_train_corpus.append(line)
        y_train.append(0)
        f.close()
    
    for tpf in train_pos_files:
        f = open(tpf, 'r', encoding="utf8")
        line = f.read()
        #line = line[:len(line)/2]
        X_train_corpus.append(line)
        y_train.append(1)
        f.close()
    
    print("Train Data loaded.")
    
    test_neg_files = glob.glob(path+"/test/neg/*.txt")
    test_pos_files = glob.glob(path+"/test/pos/*.txt")
    
    X_test_corpus = []
    y_test = []
    
    for tnf in test_neg_files:
        f = open(tnf, 'r', encoding="utf8")
        X_test_corpus.append(f.read())
        y_test.append(0)
        f.close()
    
    for tpf in test_pos_files:
        f = open(tpf, 'r', encoding="utf8")
        X_test_corpus.append(f.read())
        y_test.append(1)
        f.close()
    
    print("Test Data loaded.")
    
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    
    if shuffle:
        np.random.seed(random_state)
        indices = np.random.permutation(len(y_train))       
        
        #X_train = X_train.tocsr()
        #X_train_corpus = X_train_corpus[indices]
        X_train_corpus = [X_train_corpus[i] for i in indices]
        y_train = y_train[indices]
        #train_corpus_shuffled = [train_corpus[i] for i in indices]
        
        indices = np.random.permutation(len(y_test))
        
        #X_test = X_test.tocsr()
        #X_test_corpus = X_test_corpus[indices]
        X_test_corpus = [X_test_corpus[i] for i in indices]
        y_test = y_test[indices]
        #test_corpus_shuffled = [test_corpus[i] for i in indices]
    #else:
        #train_corpus_shuffled = train_corpus
        #test_corpus_shuffled = test_corpus
    
    return X_train_corpus, y_train, X_test_corpus , y_test

# %%
'''
Read and load the contraction list (or any text files)
'''
def load_list(filename, split_delimiter):
    vocabulary = []
    with open(filename, 'r') as f:
        for l in f:
            vocabulary.append(l.strip().split(split_delimiter))
    return np.asarray(vocabulary)

'''
Clean the HTML tags from the corpus
'''
def cleanhtml(text):
#     cleanr = re.compile('<.*?>')
#     cleantag = re.sub(cleanr, '', text)
    cleantag = re.sub(re.compile('<.*?>'), '', text)
    cleantext = cleantag.replace('br', '')
    return cleantext

# Reference :
# https://stackoverflow.com/questions/9662346/python-code-to-remove-html-tags-from-a-string

'''
Replace the contraction words into two parts (by given contraction list)
'''
def replace_contraction(corpus, cont_list):
    for i in range(0, cont_list.shape[0]):
        corpus = corpus.lower().replace(cont_list[i,0], cont_list[i,1])
    return corpus

'''
Singularize the words by its POS-tag
'''
def word_singularize(corpus):
    from textblob import TextBlob
    
    text = TextBlob(corpus)
    for tag in text.tags:
        if tag[1] == 'NNS' and tag[0] != 'yes':
            corpus = corpus.replace(tag[0], tag[0].singularize())
    return corpus

'''
Update clean corpus
'''
def update_corpus_contraction(X_corpus):
    cont_list = load_list("contraction_list.txt", ',')
    print(cont_list.shape)
    print('corpus update start')
    for i in range(0,len(X_corpus)):
        X_corpus[i] = cleanhtml(X_corpus[i])
        X_corpus[i] = replace_contraction(X_corpus[i], cont_list)
        X_corpus[i] = word_singularize(X_corpus[i])
        X_corpus[i] = X_corpus[i].replace('&', 'and')
    print('corpus update end')
    print()
    return X_corpus

'''
Count the negative and positive frequency
'''
def negative_positive_counts(X, y, word_index):
    neg_count = np.sum(X[y==0, word_index])
    pos_count = np.sum(X[y==1, word_index])    
    return neg_count, pos_count

'''
Count the ratio : log(#pos/#neg)
'''
def log_ratio_positive_negative(X, y, word_index):
    neg_count, pos_count = negative_positive_counts(X,y, word_index)
    log_ratio = np.log(pos_count+1)-np.log(neg_count+1)
    return log_ratio, neg_count, pos_count

'''
Sort top words w.r.t log ratio and write into file
'''
def sort_top_words_with_count(X, y, words,filename, top_k=10):
    log_ratio = []
    neg_count = []
    pos_count = []
    
    for i in range(0,len(words)):
        log_ratio_, neg_count_, pos_count_ = log_ratio_positive_negative(X, y, i)
        log_ratio.append(log_ratio_)
        neg_count.append(neg_count_)
        pos_count.append(pos_count_)
    
    sorted_indices_descending_abs = np.argsort(np.absolute(log_ratio))[::-1]
    
    filename = filename + '.txt'
    with open(filename, mode='w', encoding='utf8') as w:
        for i in sorted_indices_descending_abs[: top_k]:
#             print("%s\t%0.2f" %(words[i], weights[i]))
#             n_p=negative_positive_counts(X, y, i)
            w.write("%s\t%0.2f\t%d\t%d" %(str(words[i]), log_ratio[i], neg_count[i], pos_count[i]))
            w.write('\n')
        w.close()

# %% [markdown]
# ### Load the data

# %%
path = r"C:\Users\Anne Soraya\Documents\IIT_resources\Python\aclImdb"
X_train_corpus , y_train, X_test_corpus , y_test = load_imdb(path)
# Out:
# Loading the imdb data
# Train Data loaded.
# Test Data loaded.

# %% [markdown]
# ### Corpus Update
#
# Such as :<br>
# [isn't $\rightarrow$ is not] <br>
# [haven't $\rightarrow$ have not] <br>
# ain't -> are not (despite it also could be a 'is not' or 'am not')
# <br>
#
# The steps are as follows :
# 1. Remove the HTML tags
# 2. Remove the contractions
# 3. Singularize nouns

# %%
X_train_corpus_update = update_corpus_contraction(X_train_corpus)
# X_test_corpus_update = update_corpus_contraction(X_test_corpus)
# Out:
# (72, 2)
# corpus update start
# corpus update end

# %%
print(X_train_corpus_update[0])
sample_corpus = []

token = r"(?u)\b[\w\'/]+\b"
tf_vectorizer = CountVectorizer(lowercase=True, max_df=1.0, min_df=1, binary=False, token_pattern=token)
tf_vectorizer.set_params(ngram_range=(1,1))

sample_corpus.append(X_train_corpus_update[0])
X_sample = tf_vectorizer.fit_transform(sample_corpus)

word_feature = tf_vectorizer.get_feature_names()

print()
# for i in word_feature:
#     print(i)

print(sample_corpus)
print(len(word_feature))
print(X_sample.shape)
print()
print(X_sample[np.where(X_sample != 1)])
print("---")
# print(word_feature[np.where(X_sample[0,:] != 1)])

print(np.where(X_sample != 1))
'''
Here, we put the word frame to the sentences
'''

text = TextBlob(X_train_corpus_update[0])
# print(text.tags)
print()
# print(text.sentences)
sentence = []
for i in range(0, len(text.sentences)):
    sentence.append(text.sentences[i])
    
# print(sentence.shape)
print("Test")
# Out:
# silent night, deadly night 5 is the very last of the series, and like part 4, it is unrelated to the first three except by title and the fact that it is a christmas-themed horror flick.except to the oblivious, there is some obvious thing going on here...mickey rooney plays a toymaker named joe petto and his creepy son's name is pino. ring a bell, anyone? now, a little boy named derek heard a knock at the door one evening, and opened it to find a present on the doorstep for him. even though it said "do not open till christmas", he begins to open it anyway but is stopped by his dad, who scolds him and sends him to bed, and opens the gift himself. inside is a little red ball that sprouts santa arm and a head, and proceed to kill dad. oop, maybe he should have left well-enough alone. of course derek is then traumatized by the incident since he watched it from the stair, but he does not grow up to be some killer santa, he just stops talking.there is a mysterious stranger lurking around, who seems very interested in the toy that joe petto makes. we even see him buying a bunch when derek's mom takes him to the store to find a gift for him to ing him out of his trauma. and what exactly is this guy doing? well, we are not sure but he does seem to be taking these toy apart to see what makes them tick. he does keep his landlord from evicting him by promising him to pay him in cash the next day and present him with a "larry the larvae" toy for his kid, but of course "larry" is not a good toy and gets out of the box in the car and of course, well, thing are not pretty.anyway, eventually what is going on with joe petto and pino is of course revealed, and as with the old story, pino is not a "real boy". pino is probably even more agitated and naughty because he suffers from "kenitalium" (a smooth plastic crotch) so that could account for his evil way. and the identity of the lurking stranger is revealed too, and there is even kind of a happy ending of sort. whee.a step up from part 4, but not much of one. again, brian yuzna is involved, and screaming mad george, so some decent special effect, but not enough to make this great. a few leftover from part 4 are hanging around too, like clint howard and neith hunter, but that does not really make any difference. anyway, i now have seeing the whole series out of my system. now if i could get some of it out of my ain. 4 out of 5.
#
# ['silent night, deadly night 5 is the very last of the series, and like part 4, it is unrelated to the first three except by title and the fact that it is a christmas-themed horror flick.except to the oblivious, there is some obvious thing going on here...mickey rooney plays a toymaker named joe petto and his creepy son\'s name is pino. ring a bell, anyone? now, a little boy named derek heard a knock at the door one evening, and opened it to find a present on the doorstep for him. even though it said "do not open till christmas", he begins to open it anyway but is stopped by his dad, who scolds him and sends him to bed, and opens the gift himself. inside is a little red ball that sprouts santa arm and a head, and proceed to kill dad. oop, maybe he should have left well-enough alone. of course derek is then traumatized by the incident since he watched it from the stair, but he does not grow up to be some killer santa, he just stops talking.there is a mysterious stranger lurking around, who seems very interested in the toy that joe petto makes. we even see him buying a bunch when derek\'s mom takes him to the store to find a gift for him to ing him out of his trauma. and what exactly is this guy doing? well, we are not sure but he does seem to be taking these toy apart to see what makes them tick. he does keep his landlord from evicting him by promising him to pay him in cash the next day and present him with a "larry the larvae" toy for his kid, but of course "larry" is not a good toy and gets out of the box in the car and of course, well, thing are not pretty.anyway, eventually what is going on with joe petto and pino is of course revealed, and as with the old story, pino is not a "real boy". pino is probably even more agitated and naughty because he suffers from "kenitalium" (a smooth plastic crotch) so that could account for his evil way. and the identity of the lurking stranger is revealed too, and there is even kind of a happy ending of sort. whee.a step up from part 4, but not much of one. again, brian yuzna is involved, and screaming mad george, so some decent special effect, but not enough to make this great. a few leftover from part 4 are hanging around too, like clint howard and neith hunter, but that does not really make any difference. anyway, i now have seeing the whole series out of my system. now if i could get some of it out of my ain. 4 out of 5.']
# 232
# (1, 232)
# c:\users\anne soraya\appdata\local\programs\python\python36\lib\site-packages\scipy\sparse\compressed.py:248: SparseEfficiencyWarning: Comparing a sparse matrix with a nonzero scalar using != is inefficient, try using == instead.
#   " is inefficient, try using == instead.", SparseEfficiencyWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7a92663c22c9> in <module>()
#      19 print(X_sample.shape)
#      20 print()
# ---> 21 print(X_sample[np.where(X_sample != 1)])
#      22 print("---")
#      23 # print(word_feature[np.where(X_sample[0,:] != 1)])
#
# c:\users\anne soraya\appdata\local\programs\python\python36\lib\site-packages\scipy\sparse\base.py in __bool__(self)
#     256             return self.nnz != 0
#     257         else:
# --> 258             raise ValueError("The truth value of an array with more than one "
#     259                              "element is ambiguous. Use a.any() or a.all().")
#     260     __nonzero__ = __bool__
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all().

# %%
# text = TextBlob(X_train_corpus_update[2])
# print(X_train_corpus[2])
# print(text.tags)
# print()
# for sentences in text.sentences:
#     if "not" in sentences:
#         print('->', sentences)

# %%
sample_corpus = []

for i in range(30):
    sample_corpus.append(TextBlob(X_train_corpus_update[i]))
    print(i+1, ' label: ', y_train[i])
    for sentences in sample_corpus[i].sentences:
        if  "\"" in sentences:
            print('->', sentences)
    print()
# Out:
# 1  label:  0
# -> even though it said "do not open till christmas", he begins to open it anyway but is stopped by his dad, who scolds him and sends him to bed, and opens the gift himself.
# -> he does keep his landlord from evicting him by promising him to pay him in cash the next day and present him with a "larry the larvae" toy for his kid, but of course "larry" is not a good toy and gets out of the box in the car and of course, well, thing are not pretty.anyway, eventually what is going on with joe petto and pino is of course revealed, and as with the old story, pino is not a "real boy".
# -> pino is probably even more agitated and naughty because he suffers from "kenitalium" (a smooth plastic crotch) so that could account for his evil way.
#
# 2  label:  1
#
# 3  label:  0
#
# 4  label:  1
# -> even the codename that the bad guy use is dumb ("tango-tango").
# -> oh, yes: and the unintentional humour.the film opens with some truly bad and unconvincing gay banter between our go-lucky and happy character who are obviously having a "swell" time.
# -> "get off my back!"
# -> lithgow: "i have not even started climbing on your back."
# -> or, lithgow to stallone: "we had a deal, but now we only have each other!"
#
# 5  label:  1
# -> he makes us understand but a glimpse of what it is to live with such horror and futility.a mutant to be sure, chikatilo's childhood was one which produces such "monster."
#
# 6  label:  0
#
# 7  label:  0
#
# 8  label:  1
# -> "a cry in the dark" is a masterful piece of cinema, haunting, and incredibly though provoking.
# -> but the one thing that helps "a cry in the dark" never fall flat is the illiant direction.
#
# 9  label:  0
# -> skippy from "family ty" play eddie, a wussy 'metal' nerd who gets picked on.
# -> this movie is utterly laughable and has about as much to do with real metal as say, "rock star".
# -> and how anyone can root for a guy played by skippy from "family ty" i have not a clue.
#
# 10  label:  0
# -> sadly, he has to struggle with an underwritten script and some nonsensical set pieces.larsen is in "die hard" mode complete with singlet and bulging muscle, i am sure he could do better but seems satisfied to grimace and snarl through his part.the lovely erika is very decorative (even though fully clothed!)
# -> and shows some sign of "getting" acting at last.sfx are mainly poor cgi and steal from other movies.the shootout are pitiful - worthy of the a-teamnot even worth seeing for perlman - avoid
#
# 11  label:  1
# -> so, since he is currently playing in "othello", he begins to act jealous and suspicious--just like the title character.
# -> it could have been any play, though "othello" was an excellent choice because of the murder scene--which gets acted out for real later in the film.overall, a very clever film due to a lovely script--with some overtone of film noir.
#
# 12  label:  0
# -> they slog through it the best they can as the music video director says "do not worry we will make a lot of fast cut and no one will notice how bad the film is" or "we will fix it with lot of loud music" the "script" is not really a script at all, it is more like a list of clich with an ending that is a total ripoff of: -------warning - possible spoiler------ 5------4-----3-----2-----1------ the fugitive.
#
# 13  label:  0
#
# 14  label:  1
#
# 15  label:  0
# -> not because there were no fx or because we had a single cabin as the scenario for the whole film, actually that was what kept me watching it.i did not like it because the acting was shady, his "friend" are all happy and then they are mad, but you have no idea why; then they take distinct role, one is the believer, other is the antagonist, but they never really make the point!
# -> also, the lighting was terrible and i am just mentioning technical issues.in a few word, i thing the movie could have just had a "ok i am outta here!"
#
# 16  label:  1
# -> "radiofreccia" is still a good surprise in italian cinema.
# -> we are in 1975, the time of the first free radio -one of the boy of the movie creates "radioraptus".
# -> obviously luciano "liga" ligabue is neither fellini nor a movie professional, first of all he is a musician.
# -> unfortunately he will not repeat the success with his second movie "da zero a dieci" -not good at all.in "radiofreccia" actor are generally not very famous, the only star is stefano accorsi -one of the most popular young italian actor.
#
# 17  label:  1
#
# 18  label:  1
#
# 19  label:  0
# -> although quantum physic has been around for over 50 year, the film presents this information in a grandiose way that seems to be saying: "are not you just blown away by this!"
# -> for every so called "expert" that they interviewed for this film, there are score of theoretically physicist who would completely disagree.
# -> at one point, one of the "expert" says that since throughout history most of the assumption person have made about the world turned out to be false, therefore the assumption we currently hold about the world are also likely to be false.
#
# 20  label:  0
#
# 21  label:  0
#
# 22  label:  0
# -> on the face of it, one could make the case that it is about a would-be screenwriter, who at the very moment of his meeting with fate, realizes that life is hit and miss, and/or success is blind chance, as he is hurled into a "slipstream" of collision between point in time, dream, thought, and reality.
#
# 23  label:  0
# -> "azumi 2" lack just about everything that made the original so wonderful.
# -> while the first had a simple "hitlist" plot, this one has a corkscrew mess of a story, with too many dull character stabbing each other in the back so many time the potential for any sympathy or pathos is obliterated.
# -> the less said about chiaki "remember me from kill bill" kuriyama's performance the better; it suffices to say her "turn" from good to evil is about as subtle as napalm.overall, this was just a colossal disappointment.
#
# 24  label:  0
# -> clocking in at an interminable three hour and twenty minute, "salaam-e-ishq" is a pretty but superficial comic soap opera from india that regales us with six interwoven tale of romantic love (which is at least four tale too many in my estimation).filmed like a cross between an mtv music video and a super bowl beer commercial, the movie is a sprawling mishmash of exotic setting, dazzling color, sexy showgirls, high-stepping song-and-dance number, dream and fantasy sequence, winking character aside, corny dialogue and way-over-the-top comical performance - all pretty much standard-issue stuff when it comes to bollywood happening these day.
#
# 25  label:  0
#
# 26  label:  1
#
# 27  label:  0
# -> i love horror movie that ings out a real amount of mystery like say "silent hill" ( which i found to be quite good, but still, was missing something ) and movie that keeps you guessing, this i thought was one of those movie.
# -> i mentioned silent hill at first for a reason because i can see a lot of "stolen" theme from that movie in here.. all in all i would say, watch silent hill instead of this one, its better, its more scary, it has a lot more suspense and also the ending is a lot better.. and best of all, you wont feel ripped off as i did with this one.. this just seems to be one of those "i like that movie so i am gonna re-make it in my own really bad version" kinda movie.. oh and one more thing... lordi.. in a horror movie... that like trying to scare a kid with a care bear who has "hug me and i will love you forever" written on the stomach of it..
#
# 28  label:  0
# -> this was the measure of disguise, whenever we wanted to emphasize something's silliness (either on tv or anything else) we said "uh, just like power ranger" and laughed.
#
# 29  label:  1
# -> she appears like a fresh scrubbed face "tween" slight and stringy, but undeniably reese.i have always liked her as an actor, and had no idea she started this young with her career, go figure.
# -> i say that because whenever i have watched her perform, the character thus far, in each portrayal she also seemed to have her own persona that lived with that character, quite nicely in fact.anyway, my first film experience with reese was the little red riding hood parody reese did with kiefer sutherland, somehow i assumed that was her first time up "at bat" not so, well done reese
#
# 30  label:  0

# %%
for i in range(10):
    print(y_train[i])
# Out:
# 0
# 1
# 0
# 1
# 1
# 0
# 0
# 1
# 0
# 0

# %%
token = r"(?u)\b[\w\'/]+\b"
tf_vectorizer = CountVectorizer(lowercase=True, max_df=1.0, min_df=100, binary=False, token_pattern=token)
tf_vectorizer.set_params(ngram_range=(1,1))
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=100,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern="(?u)\\b[\\w\\'/]+\\b",
#         tokenizer=None, vocabulary=None)

# %%
X_matrix = tf_vectorizer.fit_transform(X_train_corpus_update)

# %%
words = tf_vectorizer.get_feature_names()
X_matrix_dense = X_matrix.todense()
indices = np.where(X_matrix_dense[0,:] != 0))
# Out:
#   File "<ipython-input-50-87a7d5b5d9ed>", line 3
#     indices = np.where(X_matrix_dense[0,:] != 0))
#                                                 ^
# SyntaxError: invalid syntax

# %%
# print(text.tags)

# for tag in text.tags:
#     if tag[1] == 'NNS':
#         print(tag[0], ' ', tag[0].singularize())
#         X_train_corpus_update[2] = X_train_corpus_update[2].replace(tag[0], tag[0].singularize())

# print(X_train_corpus_update[2])

# %% [markdown]
# ### top 100 words extraction (1-5 grams)

# %%
token = r"(?u)\b[\w\'/]+\b"
tf_vectorizer = CountVectorizer(lowercase=True, max_df=1.0, min_df=100, binary=True, token_pattern=token)

# %%
tf_vectorizer.set_params(ngram_range=(1,1))
X_train = tf_vectorizer.fit_transform(X_train_corpus_update)
words = tf_vectorizer.get_feature_names()

# %%
len(words)

# %%
sort_top_words_with_count(X_train, y_train, words, '1gram', top_k=100)

# %%
def generate_grams_list():
    for i in range(1,6):
        print('Processing',i,'grams')
        tf_vectorizer.set_params(ngram_range=(i,i))
        X_train = tf_vectorizer.fit_transform(X_train_corpus_update)
        words = tf_vectorizer.get_feature_names()

    #     clf = LogisticRegression(penalty='l2', C=1, random_state=42)
    #     clf.fit(X_train, y_train)

        filename=str(i)+"gram"
        sort_top_words_with_count(X_train, y_train, words, filename, top_k=100)

    #     del clf
        del X_train
        del words

# %%
#generate_grams_list()

# %%
tf_vectorizer.set_params(ngram_range=(2,2))
X_train = tf_vectorizer.fit_transform(X_train_corpus_update)

# %%
words = tf_vectorizer.get_feature_names()

#print(words)

for i in range(0,len(words)):
    if 'not scary' in words[i]:
        index=i

#not_scary_slice = np.array(X_train[:,index])
#print(not_scary_slice)
corpus_indices = []

for i in range(0, X_train.shape[0]):
    if X_train[i, index] == 1:
        corpus_indices.append(i)
j=1
for i in corpus_indices:
    text = TextBlob(X_train_corpus_update[i])
    print(i, ' label: ',y_train[i])
    for sentences in text.sentences:
        if 'not scary' in sentences:
            print(' .', sentences)
# Out:
# 3  label:  1
# 28  label:  1
# 61  label:  1
#  . the cinematography enhances the story, keeping the mood dank and dense and primarily confined to the condemned building.
# 126  label:  1
# 127  label:  1
# 132  label:  0
# 139  label:  0
# 145  label:  1
# 153  label:  0
# 170  label:  1
# 218  label:  0
# 223  label:  1
#  . the viewer may feel a lot better coming out of the cinema after part 1 than part 2 but that is the reality of che is life and not in my opinion any fault of the director.
# 227  label:  0
# 229  label:  1
#  . we currently have in the cinemas the austen biopic "becoming jane", and itv have recently produced three tv movie based on austen novel.
# 249  label:  1
# 271  label:  1
# 278  label:  1
# 350  label:  0
# 355  label:  0
# 384  label:  0
# 476  label:  0
# 495  label:  0
# 499  label:  1
# 524  label:  0
# 529  label:  0
# 543  label:  1
# 557  label:  1
# 584  label:  0
#  . to sum it up, this is pure cinema barf drenched in the chocolate syrup known as nudity, and topped with the cherry of horrible acting as only a porn star could deliver.
# 667  label:  0
# 708  label:  0
# 722  label:  0
# 733  label:  0
# 748  label:  0
# 771  label:  1
# 780  label:  1
# 802  label:  0
# 823  label:  0
# 858  label:  0
# 878  label:  0
# 880  label:  1
# 887  label:  0
# 888  label:  0
# 900  label:  1
# 961  label:  1
# 970  label:  1
# 1041  label:  1
#  . moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released.
# 1145  label:  1
# 1162  label:  0
# 1164  label:  0
# 1201  label:  0
# 1269  label:  0
# 1275  label:  0
# 1276  label:  0
# 1300  label:  0
# 1305  label:  1
# 1332  label:  0
#  . it was made by a grindhouse cinema owner for an extreme low budget.
# 1360  label:  0
# 1381  label:  0
# 1384  label:  1
# 1399  label:  0
# 1432  label:  0
# 1444  label:  1
# 1457  label:  0
# 1497  label:  0
# 1511  label:  0
# 1523  label:  1
# 1546  label:  1
# 1562  label:  0
# 1708  label:  0
# 1720  label:  0
# 1738  label:  0
# 1747  label:  0
# 1753  label:  1
# 1767  label:  1
# 1785  label:  1
# 1801  label:  0
# 1811  label:  1
# 1911  label:  0
# 1930  label:  1
#  . but it is also just a really strong feat of cinematic technique.
# 1932  label:  1
# 1936  label:  1
# 1966  label:  0
#  . there is nothing cool, hip, or clever about this film-- liking it just reveals an ignorance of true art cinema.
#  . it is fine to explore a film to see if you can find cinematic device that are ingeniously artistic, but you cannot uncover a hidden meaning if one is not there!
#  . to do that you need to view and review a real piece of cinema.
# 1997  label:  0
# 2000  label:  0
# 2013  label:  0
# 2020  label:  1
# 2086  label:  0
# 2131  label:  0
# 2159  label:  0
# 2240  label:  0
# 2260  label:  0
# 2278  label:  0
# 2299  label:  0
# 2363  label:  0
# 2375  label:  1
# 2390  label:  1
# 2407  label:  0
# 2426  label:  1
# 2467  label:  0
#  . what with the recently deceased ruben gonzalez piped through speaker in this old cinema-ballroom and a cuban flag hanging from peeling stucco rocaille motif, the scene was set for a riproaring celeation of engaged filmmaking and synchronised hissing at the idiocy of helms-burton.
#  . and the cinema's peeling paint gradually became more interesting than the shoddy mess on-screen.the storyline of nada mas promise much.
# 2539  label:  0
# 2549  label:  0
# 2584  label:  0
# 2626  label:  0
# 2638  label:  0
# 2650  label:  1
#  . directed by govind nihalani, this is definite cop film of indian cinema.
#  . the film was made absolutely off beat tone in the time when person did not pay much attention to such kind of cinema and yet it becomes a most sought after cop film in class and mass audience when it released.
#  . for om puri its first eakthrough in mainstream hindi cinema and he delivered a class performance as inspector velankar.
# 2735  label:  1
# 2778  label:  0
# 2819  label:  0
# 2844  label:  1
# 2846  label:  0
# 2863  label:  0
# 2910  label:  0
# 2914  label:  1
# 2939  label:  0
# 2984  label:  0
# 3004  label:  1
#  . the film is also full of both subtle and not so subtle visual symbolism which helps make it a unique and satisfying cinematic experience.
# 3054  label:  0
# 3068  label:  1
# 3091  label:  0
# 3108  label:  1
# 3132  label:  1
# 3137  label:  0
# 3174  label:  0
# 3180  label:  1
# 3187  label:  0
# 3199  label:  1
# 3205  label:  1
# 3228  label:  1
# 3283  label:  0
# 3298  label:  0
#  . jonathan craven's screenplay could have been written in a weekend, and given the speed with which this movie made it into cinemas, probably was.
#  . 'the descent' (on which sam mccurdy, coincidentally, also worked as cinematography) proved that even this most derivative of sequence can still be carried out with genuine originality and suspense, but we see no such innovation here.
# 3319  label:  1
#  . even the director of the berlinale, obviously a hardened viewer of cinema, confessed to having been caught unaware and found himself crying three quarter's way into this unashamedly sentimantal experience.but what really surprised me were the review that came after.
#  . a wicked old trick he so seamlessly applied in the tora-san series, and later, in tasogare sebei.after lulling the audience into a sort of narrative comfort zone, he throws us into a realm of emotion rarely explored in cinema.this, to me, is the most effective cinematic tool of all.
#  . and proof of its effectiveness was a thousand wet piece of kleenex, thrown into a litter bin just outside of that thousand-seater cinema hall.now if only some reviewer would resist being so caught up with being smart that they forget what cinema is really about.
# 3349  label:  0
# 3356  label:  1
#  . anyone who's never seen it, horror fan or not, should do his cinematic homework right now.
# 3362  label:  1
#  . the direction holds up as the cast carries the story in lovely colour cinematography.
# 3364  label:  0
# 3386  label:  1
# 3398  label:  1
# 3407  label:  1
# 3463  label:  1
# 3497  label:  1
# 3536  label:  0
# 3578  label:  1
# 3617  label:  1
# 3662  label:  0
# 3670  label:  1
# 3685  label:  0
# 3695  label:  1
# 3764  label:  1
# 3854  label:  1
#  . if there is such a thing as "intellectual horror" cinema, this film is it.
# 3885  label:  0
# 3888  label:  0
# 4013  label:  0
#  . surely being in a position like his you'd think he had try and make a point about cinema a little more intelligently than this.
# 4049  label:  0
#  . the cinematography was great.
# 4055  label:  1
# 4065  label:  0
# 4127  label:  0
# 4131  label:  0
# 4185  label:  0
# 4216  label:  1
# 4235  label:  0
# 4277  label:  0
# 4316  label:  1
# 4322  label:  1
# 4333  label:  1
# 4365  label:  0
# 4375  label:  0
# 4381  label:  1
# 4475  label:  1
# 4477  label:  0
# 4504  label:  0
# 4567  label:  1
# 4607  label:  0
# 4648  label:  0
# 4662  label:  0
# 4691  label:  1
# 4826  label:  0
# 4894  label:  1
#  . the technical production was beautiful, with cinematography by the legendary jame wong howe, a fine score by george duning, more-than-clever set by louis diage and gown by jean louis.
# 4903  label:  0
#  . i am not sure what dragged me into the cinema to watch this movie, but few minute after it started, i wanted to leave the theater.
#  . i do not want to go to cinema to have a computer game on my screen, do not know about you...animation was also a disgrace.
# 4931  label:  0
# 4945  label:  1
# 4961  label:  1
# 4971  label:  1
# 4974  label:  1
# 4979  label:  1
# 4995  label:  0
# 5013  label:  0
# 5022  label:  1
# 5037  label:  1
# 5056  label:  0
#  . it is as if he completely forget everything he knew about cinema and started all over again - only to get sloppish results.in a few word, this film does not deserve your time.
# 5106  label:  1
# 5146  label:  0
# 5183  label:  0
# 5197  label:  1
# 5202  label:  0
# 5216  label:  1
# 5257  label:  1
# 5262  label:  1
# 5267  label:  1
# 5271  label:  1
#  . as far as indie cinema goes, this may not be perfect from a technical standpoint, but from an artistic one, it is very close.
# 5291  label:  1
# 5320  label:  1
# 5346  label:  1
# 5365  label:  1
#  . the actress does an incredible job with this role which i imagine was not easy to play.dog bite dog also features some really eathtaking cinematography, all though it is unfortunately rather uneven.
# 5402  label:  0
# 5442  label:  1
# 5464  label:  0
#  . i first heard of unisol 2 when i drove past a cinema when i was on holiday in america.
# 5469  label:  0
#  . so now we know that the cinematographer was a rank amateur, as well.
#  . in fact, two time during the film it seemed that it was finally over and person started to get up to leave (this was one of the side effect of the cinematographer's "total darkness" technique).
# 5483  label:  0
# 5486  label:  0
# 5517  label:  0
# 5534  label:  0
# 5539  label:  1
# 5551  label:  1
#  . if there is any sort of criticism it is that it feels too much like a tvm rather than a cinematic movie but believe me i can live with that and is essential viewing to anyone who thinks religion is the opium of the mass
# 5594  label:  1
# 5629  label:  1
# 5691  label:  0
# 5707  label:  0
# 5718  label:  1
# 5745  label:  0
# 5755  label:  0
# 5765  label:  1
# 5796  label:  0
# 5820  label:  0
# 5826  label:  0
# 5867  label:  0
#  . and that, lady and gentleman, is impressive indeed, for i have seen many a bad movie.this masterpiece of modern cinema consists of two interwoven part, alternating between a silly and contrived plot about an extremely annoying photographer, abandoned by her husband and forced to take anti-depressant to survive, and a bunch of talking head going on about how quantum physic supposedly justify their new-agy pseudo-philosophy.
# 5933  label:  1
# 5937  label:  0
# 5948  label:  1
# 5994  label:  1
# 6006  label:  1
# 6017  label:  1
# 6024  label:  0
# 6045  label:  0
# 6059  label:  1
# 6106  label:  0
# 6146  label:  0
# 6164  label:  0
# 6166  label:  1
# 6188  label:  0
# 6246  label:  0
# 6253  label:  0
#  . unnecessary nude scene every five minute, a story that must have been penned in an our, and really just awful scenery, music, and cinematography.
# 6277  label:  0
# 6285  label:  1
# 6324  label:  1
# 6391  label:  1
# 6404  label:  0
# 6419  label:  0
# 6481  label:  1
# 6487  label:  0
# 6521  label:  1
# 6522  label:  1
#  . we go to the cinema every day and allow ourself to believe what is happening on the screen is real.
# 6557  label:  0
# 6598  label:  0
# 6603  label:  1
# 6627  label:  0
# 6645  label:  1
# 6658  label:  1
# 6674  label:  0
# 6686  label:  1
# 6716  label:  0
#  . i do not think so.this show is purely for jay chou fan, and the film lacks a depth in term of character development, cinematography style and unfolding of plot.anybody notice that the captain of the basket team (forgot his name) and the idolized player li xiao look so similar to each other, to the extent that you'd think they were the one and same person?
# 6752  label:  0
# 6785  label:  1
# 6803  label:  0
# 6836  label:  0
# 6837  label:  1
# 6875  label:  0
# 6911  label:  0
# 6925  label:  0
# 6960  label:  0
# 6961  label:  0
# 6980  label:  0
# 7023  label:  0
# 7062  label:  1
# 7063  label:  1
# 7077  label:  0
# 7118  label:  1
# 7170  label:  0
# 7174  label:  0
# 7194  label:  0
# 7214  label:  1
# 7220  label:  0
# 7241  label:  0
# 7276  label:  1
# 7279  label:  0
# 7281  label:  1
#  . one of the most important artistic movement in the history of cinema was without a doubt german expressionism, the highly atmospheric style of film-making developed during the 20s in berlin.
#  . (1920) and "nosferatu, eine symphonie de grauen" (1922) were the most famous direct result of this movement, and while the movement did not have a long life, its enormous influence over cinema can still be felt today, specially in the horror genre.
#  . written at a time where cinema in germany was still being developed as an art form, "der student von prag" shows a real willingness to actually use cinema to tell a fully developed story beyond a camera trick or a series of scene.
#  . while a bit poor on its character development (specially on the supporting character), ewer manage to create an interesting and complex protagonist in the person of balduin.while "der student von prag" was paul wegener's directorial debut and stellan rye's second film as a filmmaker, it is very clear that these two pioneer had a very good idea of what cinema could do when done properly.
#  . giving great use to guido seeber's cinematography, the two young filmmaker create a powerful gothic atmosphere that forecasts what the german filmmaker of the following decade would do.
#  . however, "der student von prag" is a very interesting early attempt at a complex tale of horror and suspense in film that, while inferior to what other filmmaker were doing at the time, left a powerful impression in history.as the direct predecessor of the german expressionist movement, it is hard to deny the enormous importance that "der student von prag" has in the history of german cinema, probably in the history of cinema in general.
# 7301  label:  1
# 7312  label:  0
# 7328  label:  1
# 7373  label:  0
# 7381  label:  0
# 7397  label:  1
# 7404  label:  0
# 7433  label:  1
# 7554  label:  0
# 7670  label:  1
# 7676  label:  0
# 7690  label:  1
# 7778  label:  1
#  . i popped it in and was glued to the beautiful cinematography, delightful score and moving plot from beginning to end.
# 7784  label:  1
#  . the fact that it is one of the only remaining japanese film from this era causes person to say that it "started japanese cinema" and was "unlike anything the west ever made."
# 7787  label:  0
# 7800  label:  0
# 7801  label:  1
# 7836  label:  1
# 7852  label:  0
#  . and it is never something that is not fascinating to *look* at, with miguel garzon's cinematography a morbid delight.
# 7924  label:  0
# 7936  label:  1
# 7952  label:  0
# 7973  label:  0
# 8060  label:  0
# 8065  label:  0
# 8081  label:  0
# 8091  label:  0
# 8139  label:  1
# 8185  label:  1
# 8221  label:  0
#  . when i first saw this film in cinema 11 year ago, i loved it.
#  . i still think the directing and cinematography are excellent, as is the music.
# 8418  label:  0
# 8429  label:  0
# 8436  label:  0
# 8439  label:  0
# 8497  label:  0
# 8559  label:  0
# 8573  label:  0
# 8598  label:  0
# 8615  label:  0
# 8670  label:  0
# 8704  label:  0
# 8736  label:  1
# 8741  label:  1
# 8763  label:  0
# 8824  label:  0
# 8836  label:  1
# 8861  label:  0
# 8866  label:  1
# 8886  label:  1
# 8964  label:  1
# 8994  label:  1
# 9000  label:  0
# 9058  label:  0
# 9100  label:  1
# 9137  label:  1
#  . the most bizarre of the cinematic sub-genre is the so called "the great lady of the grand guignol": camp horror film which combined over-the-top melodrama with gothic thrill and always starred by seasoned and almost forgotten actress from hollywood golden age in unflattering role of either long suffering victim or screeching evil harpy.
# 9152  label:  0
# 9190  label:  0
# 9205  label:  0
# 9219  label:  0
# 9224  label:  0
# 9226  label:  0
# 9229  label:  0
# 9270  label:  1
#  . when i saw it a second time in an australiumn cinema class, i realized a second point: communication issue.
# 9276  label:  1
#  . everything about this movie is good - cinematography, story pace and most of all the end.
# 9292  label:  0
# 9317  label:  0
# 9349  label:  0
# 9377  label:  0
# 9395  label:  1
# 9398  label:  1
#  . a good array of character and point of view; and singleton does not take side in the story - many of the character are unsympathetic, and he does a good job of interspersing the panther and supremacist scene together to show the folly on both side.much of the cinematography was excellent; i especially loved the scene where kirsty swanson gets intimate with taryn and wayne each scene spliced together really well.
# 9411  label:  0
# 9446  label:  1
# 9451  label:  0
# 9479  label:  0
# 9481  label:  0
# 9509  label:  0
# 9583  label:  0
# 9592  label:  1
# 9628  label:  0
# 9714  label:  1
# 9715  label:  1
# 9726  label:  0
# 9729  label:  0
# 9741  label:  1
# 9758  label:  1
# 9768  label:  0
# 9783  label:  1
# 9803  label:  1
# 9834  label:  0
#  . when i first started watching this movie last night on cinemax, i was shocked that it had been made.
# 9873  label:  0
# 9918  label:  0
# 9940  label:  0
# 9956  label:  0
# 9963  label:  0
# 9971  label:  1
#  . the cinematography is quite nice, a lot of pretty summer scene at the island dock, some newfound teenage love, nice diving weather and a general feeling of "perfect".
#  . and, again, the cinematography is really nice./medusa 2001
# 9977  label:  0
# 9986  label:  0
# 10049  label:  0
# 10071  label:  1
# 10101  label:  0
# 10110  label:  1
# 10121  label:  1
# 10148  label:  0
#  . since he cannot read his sole inspiration is the movies.true, the cinema is not such a bad place to start, since it has generally escaped the onslaught of "realism".
# 10190  label:  0
# 10198  label:  1
# 10219  label:  1
# 10232  label:  0
# 10248  label:  1
# 10254  label:  0
# 10255  label:  1
#  . what those thirty-three person experienced in awe that cold day of december was the very first public screening of a moving picture being projected on a screen; history was being written and cinema as we know it was born that day.of the 10 short movie that were shown during that historic day, "la sortie de usines lumière" (literally "exiting the lumière factory") was the very first to be screened.
#  . it definitely was not the first movie the other shot that year, and it probably was not the best of the 10 movie shown that day (personally i think that "l' arroseur arrosé" was the best of the 10); however, it is really meaningful that the very first movie was the opening of a pair of gate, as literally, this movie opened the gate to cinema as we know it.
# 10266  label:  0
# 10271  label:  1
# 10313  label:  1
# 10330  label:  1
# 10335  label:  1
# 10342  label:  0
# 10379  label:  1
# 10409  label:  1
# 10458  label:  1
# 10475  label:  0
# 10487  label:  1
# 10492  label:  1
#  . starewicz and his helper painstakingly manipulated a cast of flexible insect figure to tell this story, paving the way for the like of willis o'brien, george pal, ray harryhausen, and legion of modern digital effect creators.the cameraman's revenge is only about 10 minute long, but pack in lot of amusing detail as the story follows the amorous adventure of two beetle from their home to a nightclub, a hotel, a cinema, and, eventually, a prison cell.
#  . there are two ief dance number at the nightclub (performed by a frog and a dragonfly), a scuffle between a beetle and a grasshopper, and a large-scale donnyook at the cinema, which ends with the projector bursting into flame.
# 10593  label:  0
# 10628  label:  0
# 10666  label:  0
# 10718  label:  1
#  . though it is adult cinema, i think mature-minded child from about seven onward would really appreciate this film (as long as they can read subtitle).it is remarkable that a repressive country like iran is able to produce film of such quality by the like of panahi and kiarostami.
# 10838  label:  0
# 10936  label:  0
#  . just like mely' "a trip to the moon", critic have hailed this as being the film that introduced the western genre into modern cinema.
#  . "the great train robbery" has lost its space in the time capsule of cinema.grade: ** out of *****
# 10939  label:  1
# 10954  label:  1
#  . this is definitely one of the high point in cinema history.
# 10968  label:  0
# 11021  label:  0
# 11033  label:  0
#  . avoid this film, a little bit of good cinematography and some naked shot, would be almost acceptable if i was 14 and had not seen jenna jameson naked a million time.
# 11085  label:  1
# 11115  label:  1
# 11172  label:  1
#  . i did not see this at the cinema because it was never released theatrically over here...but it is popularity on video during the mid to late eighty secured it is cult status and eventually led to a (sadly, mediocre) dvd release in 2002. if you are not a fan of creepy movie or rock music then this probably is not your cup of tea...but, trust me, there are worse film of this type out there...and, despite average acting and some outrageously ridiculous situation, trick or treat is most definitely a wailing riff above the usual horror fare.
# 11178  label:  0
# 11189  label:  1
# 11212  label:  0
# 11214  label:  0
# 11229  label:  0
# 11233  label:  1
# 11236  label:  0
# 11270  label:  0
# 11278  label:  0
# 11281  label:  0
# 11322  label:  0
# 11330  label:  0
#  . it makes resident evil look like cinematic glory.
# 11337  label:  1
# 11401  label:  1
# 11417  label:  1
# 11424  label:  0
# 11451  label:  0
# 11488  label:  1
# 11515  label:  1
# 11575  label:  1
# 11593  label:  1
#  . the scene with the locust is done exceedingly well and the rest of th movie really looks good warranting the best cinematography award at the oscar in that year.
# 11619  label:  0
#  . the (relative) arthouse boom of the 1960 (especially with the nouvelle vague) allowed for a huge influence of european cinema in hollywood.
# 11635  label:  0
# 11647  label:  1
# 11662  label:  0
# 11664  label:  0
# 11684  label:  0
# 11707  label:  0
# 11775  label:  1
# 11800  label:  1
# 11812  label:  1
#  . great viewing for art cinema lover.
# 11824  label:  1
# 11829  label:  1
#  . the man behind 'seryozha, sovsem propashchiy (1972) which is an adaptation of mark twain the adventure of huckleberry finn, 33, ya shagayu po moskve (1964) aka walking the street of moscow, ne goryuy (1969) aka do not grieve, afonya (1975), mimino (1977), osenniy marafon (1979) aka autumn marathon or sad comedy which is a very fitting title for this movie as well as for the whole genre that danelium practically invented, and the cult favorite for over 20 year kin-dza-dza (1986), is illiant and deserves our true love and genuine gratitude for the unforgettable moment of cinematic happiness.
# 11872  label:  1
# 11877  label:  0
# 11959  label:  0
# 12001  label:  1
# 12068  label:  1
# 12107  label:  0
# 12150  label:  0
#  . for some reason, director john boorman and cinematographer seamus deasy selected to film this movie in black-and-white while its style and presentation are clearly the element that belong to a full-fledged color film.
#  . the cinematography is also far too blown out with high lighting key that seem very distracting and give the movie a very video-game-like quality that i found simply annoying.
# 12171  label:  0
# 12173  label:  0
# 12195  label:  0
# 12207  label:  0
# 12240  label:  0
# 12282  label:  0
# 12336  label:  1
# 12371  label:  1
# 12381  label:  1
# 12394  label:  0
# 12415  label:  0
# 12429  label:  1
# 12454  label:  0
# 12464  label:  0
# 12483  label:  0
#  . after all, shoe- and foot- fetishist are offered so little in modern cinema, so it is nice to see that someone out there cares.kotm, or rather, klotlmas, offers more than meets the eye.
#  . they probably hired some passers-by and shoved the camera into their hand...go to http://rateyourmusic.com/~fedor8, and check out my "tv and cinema: 150 worst case of nepotism" list.
# 12490  label:  1
# 12507  label:  1
# 12524  label:  1
# 12550  label:  1
# 12575  label:  0
# 12695  label:  0
# 12731  label:  1
#  . this film does not fail to engage and move, even in 2008 to an audience only familiar with modern over-produced sound and computer enhanced techniques.the experience of the movie goer in 1922 who could only see this in a cinema with other on their big screen must have been truly profound and a thoroughly satisfying experience.one has to ask could a film maker today make a two hour silent movie and make it interesting and achieve the same structure tempo and balance as this movie has.
# 12733  label:  1
# 12742  label:  0
# 12789  label:  0
# 12802  label:  0
# 12808  label:  1
# 12809  label:  0
# 12824  label:  0
# 12827  label:  0
# 12849  label:  1
# 12867  label:  0
#  . there was a very big sag in the middle of the movie that was exceptionally boring.except for acting, which i felt was consistently strong, this movie failed in almost every aspect of cinema.
# 12878  label:  0
# 12903  label:  0
# 12909  label:  1
# 12967  label:  0
# 12971  label:  0
# 12993  label:  1
# 13000  label:  0
# 13057  label:  1
#  . mark burnett may have made a lot of crap in his time but his handling of the cinematography is excellent as he makes nyc look like a character unto itself.
# 13063  label:  0
#  . a nice philosophy and a true shame that band, having destroyed the full moon studio through possible shoddy business dealing became so desperate for home cinema profit that he started making exactly what the likes of blockbuster wanted and therefore sacrificed creativity and originality.
# 13066  label:  1
# 13070  label:  0
# 13124  label:  1
# 13132  label:  0
# 13253  label:  1
# 13255  label:  0
#  . the fact that i cared less about the character than i did about the colour of the cinema carpet did not really add to the effect, either.
#  . mainstream cinema seems to be going downhill and film like this worsen the situation.
# 13268  label:  0
#  . that the reason i think hollywood started to use cartoon in movie with actor like this you must forget the art of cinema , be sure that you ll have ton of pop corn to consume for time to pass till this movie ends also get many cola's hamburger your laptop your cellphone this movie can be used easily in a restaurant but for sure not in a theater , my dog who is always next to my family when watching a movie left the building.the sure thing is that this movie is referring to person with no demand from the cinema art.the only thing that this movie can be used is for watching it when making the supermarket shopping list.i am giving 2 star for supporting the india's cinema effort but for nothing more or less..
# 13288  label:  1
# 13290  label:  0
# 13309  label:  0
#  . really the worse movie i have ever seen(at the cinema).
#  . i saw it when it came out in a cinema in brighton.
# 13311  label:  1
#  . i do not know if secret sunshine is typical of korean cinema but i am off to the dvd store to discover more.
# 13376  label:  0
# 13410  label:  0
# 13437  label:  0
# 13466  label:  1
# 13468  label:  0
# 13505  label:  1
# 13565  label:  0
# 13606  label:  0
# 13608  label:  0
# 13681  label:  1
# 13684  label:  0
# 13745  label:  0
# 13752  label:  1
# 13755  label:  0
# 13785  label:  0
#  . i mean it would be a reasonable excuse if this were some junior high schooler's "production" for his first cinema class, but the referenced "artist" behind this dreck was twenty-six at the time of this miscarriage.
# 13802  label:  0
#  . and i bet heinrich harrer was, too... 3 star, just for the cinematography.
# 13806  label:  0
# 13810  label:  0
# 13824  label:  1
# 13891  label:  0
# 13904  label:  0
# 13938  label:  1
# 14054  label:  0
# 14057  label:  1
# 14203  label:  1
# 14211  label:  1
# 14239  label:  1
# 14278  label:  0
#  . it is now 7 or 8 year since i watched it during its 1 week run at the cinema before it was pulled, yet it sticks in my mind for being easily the most terrible film i have ever seen.i am only making these comment, and indeed the only reason i went to see the film, is because of the amusing fact that my other eddie appeared in it as the second 'heavy' in the pub scene.
#  . having seen the film, it appeared that nobody in it required any acting experience whatsoever.i remember there were about 8 person in the whole cinema - and this was just a couple of day after it had been released.
# 14285  label:  1
#  . has there ever been a more enigmatic ending in cinema?
#  . shelley duvall gives one of the most annoying performance in cinematic history  probably on purpose, to give jack's character more of a reason to snap  and danny lloyd is no better, but jack is a powerhouse.
#  . its strangeness perfectly reflects the hotel, the mood, and the entire film itself.i know king does not like this film, but king's input on cinema is nothing to ag about.
# 14369  label:  1
# 14396  label:  1
# 14472  label:  1
# 14489  label:  0
# 14527  label:  1
# 14533  label:  1
# 14549  label:  0
# 14560  label:  0
# 14594  label:  0
#  . dane cook, sigourney weaver and steve martin add to the cast greatness.another pregnancy movie has hit the cinema world.
# 14657  label:  0
# 14658  label:  1
# 14672  label:  1
# 14787  label:  1
#  . the cinematography itself is quite eye-catching and the set, costume and location are elaborate.
# 14840  label:  1
# 14852  label:  1
# 14861  label:  0
#  . before the film started i was surprised that there were only ten person in the cinema on a friday night shortly after the movie had opened in japan.
#  . everyone i saw walking out of that cinema had look of confusion and disappointment on their faces.
# 14882  label:  0
# 14913  label:  0
# 14927  label:  1
# 14993  label:  1
# 15020  label:  0
# 15022  label:  1
# 15054  label:  0
# 15089  label:  0
# 15145  label:  1
# 15187  label:  0
# 15191  label:  0
# 15215  label:  1
# 15229  label:  0
# 15238  label:  0
# 15259  label:  0
# 15288  label:  0
# 15305  label:  0
# 15342  label:  1
# 15410  label:  0
# 15412  label:  0
# 15460  label:  0
# 15472  label:  1
# 15477  label:  0
#  . it looked like someone with cereal palsy was holding the camera (no offense meant to cp sufferer, but i do not think you would expect to get much work as a cinematographer!)
# 15568  label:  0
# 15616  label:  0
# 15706  label:  0
# 15772  label:  1
# 15780  label:  1
# 15792  label:  0
# 15817  label:  1
# 15879  label:  1
#  . rafi, the lyric by kaif bhopali and not to mention the cinema photography when the sailing boat goes out against the black background and the shining star.
#  . but one actor who did not change in his looks was the late raj kumar, who falls in love with her and especially her foot, after he accidentally goes into her train cabin and upon seeing them, he leaves a note describing how beautiful they are.conclusion: pakeezah is a beautiful romantic story that, if at all possible should be viewed on large screen just for the sake of the cinema photography and song.
# 15887  label:  1
# 15923  label:  0
# 15944  label:  0
# 15945  label:  1
# 15952  label:  0
# 15974  label:  1
# 16028  label:  0
# 16033  label:  1
# 16044  label:  1
# 16074  label:  1
# 16136  label:  0
# 16148  label:  1
#  . it is an oddity of the cinema, and is very much worth seeing.
# 16186  label:  0
# 16240  label:  1
# 16290  label:  1
# 16318  label:  0
# 16340  label:  0
# 16378  label:  1
# 16393  label:  1
# 16399  label:  0
# 16406  label:  1
# 16447  label:  0
#  . likewise i doubt if it cost too much produce and had one eye on the dvd market rather than cinema distribution and i will state that it is slightly better than 1972's death line which also featured a murderous cannibal hiding in the london underground .
# 16459  label:  0
# 16464  label:  1
# 16467  label:  0
# 16496  label:  1
# 16535  label:  0
# 16556  label:  0
#  . "nightmare" is a dreadful piece of exploitative horror cinema, but hey, at least i gave you a golden tip to make it more digestible.
# 16573  label:  1
# 16610  label:  0
# 16731  label:  0
# 16759  label:  0
#  . i consider human who waste considerable amount of money to be evil because the money could have used to feed and clothe quite a few person instead of hurting 80 percent of those who saw it in the cinema and giving 20 percent, which are idiot, a good opportunity to show just how much of an idiot they are.
# 16877  label:  1
# 16884  label:  0
# 16904  label:  1
# 16908  label:  1
# 16935  label:  1
# 16944  label:  0
# 16974  label:  0
# 17189  label:  1
#  . everyone knows the character, even though no one has ever seen a film featuring him in the cinema.
# 17212  label:  1
# 17218  label:  0
# 17225  label:  1
#  . however, hollywood did beckon him one last time to his old seafaring way – albeit for a modestly-budgeted universal picture rather than a warner brother ‘a’ production to which he had been accustomed when at his peak… still, the glorious technicolor cinematography leaps off the screen here and, while an older and flabbier flynn may look like the pale shadow of his former self, his red-headed leading lady maureen o’hara has a field day as a tomboyish buccaneer leader who deep down crave romance and wants to be treated like a lady.
# 17227  label:  0
# 17252  label:  1
# 17259  label:  0
# 17295  label:  0
# 17416  label:  0
# 17421  label:  1
# 17503  label:  0
#  . i just could not help but watch the film for the utter baseless aspect of it all (the excellent cinematography sorta makes it easier to watch).
# 17525  label:  0
#  . the only kudos i can give the film are in regard to several scene shot as newscast, but the technique is so used in cinema today that this film did little to further it.
# 17546  label:  0
#  . billy chung siu hung's (the bloody swordplay film assassin from 1993) film love to kill (hong kong, 1993) is among the strongest product of the category iii boom that inhabited the hk cinema in early ninety.
#  . the imagery and happening are something never found in the western cinema, at least in mainstream, and it all becomes even more mind-blowing when some/most taboos for westerner, like violence and perversion witnessed by a child, are oken in these film so often that reading the plotline alone would make most viewer feel sick, and that goes perfectly especially for this film too.the film still has a rather interesting and creepy soundtrack in the tradition of the mantioned dr. lamb which practically started the whole boom in 1992. usually the music and soundtrack in hk film is interesting and adds to the imagery, especially in these terror film.
#  . also the cinematography is worth mantioning as the film bathe, especially in the finale, in blue color and camera lens (as does assassin, too), and the raging storm is captured nicely on the camera.
#  . (hk) cinema is meant to be and can be more and film like love to kill are only commercial parasite living among the real piece of the art.
# 17548  label:  0
# 17560  label:  0
# 17612  label:  0
# 17620  label:  1
# 17668  label:  1
# 17673  label:  1
# 17721  label:  0
#  . harsh, yes, but i call 'em like i see 'em.i saw this in the late 80's, and it was truly one of the most awful, boring film i have ever forced myself to watch.yes, the cinematography is lovely.
# 17765  label:  1
# 17785  label:  1
# 17821  label:  1
# 17827  label:  0
# 17835  label:  0
# 17839  label:  0
#  . surely there are some nice person in the country, filmmaker?in its defense, "this is not a love song" does contain a couple of good, suspenseful moment, but it is hard to see this film doing anything other than going straight to video, or, at a push, getting a very limited cinema release.
#  . maybe british cinema could actually get kick-started again if the right money stopped going to the wrong person.
# 17864  label:  0
# 17902  label:  0
# 17928  label:  0
# 17929  label:  0
# 18005  label:  0
# 18011  label:  1
# 18026  label:  0
# 18039  label:  1
# 18081  label:  1
# 18084  label:  1
# 18119  label:  0
# 18120  label:  1
# 18148  label:  1
#  . just think of the massacre in the bar compared to the scene in which the vampire tries to seduce zoey in the ruin: the bar-massacre is what you expect from american popcorn-entertainment, the seducing-zoey-in-the-ruin-scene is almost european-like cinema (the movie is eager to tell us more about the relationship between zoey and the vampire, but refuses answer at the same time.
# 18268  label:  0
# 18288  label:  1
# 18291  label:  1
# 18316  label:  0
# 18337  label:  0
# 18359  label:  1
# 18362  label:  1
# 18403  label:  0
# 18425  label:  0
# 18466  label:  0
# 18549  label:  0
# 18555  label:  1
# 18657  label:  0
# 18659  label:  0
# 18690  label:  0
# 18886  label:  0
# 18898  label:  1
# 18917  label:  0
#  . when you go at an open air cinema under the greek summer night you usually do not care what the movie is!
# 18930  label:  0
# 18943  label:  0
# 18957  label:  1
# 19013  label:  1
# 19026  label:  0
# 19115  label:  0
# 19137  label:  0
#  . yet, not only is this first scene the longest scroll text in the history of cinema, but it also makes no sense.
# 19171  label:  0
# 19216  label:  0
#  . it is really more of a film curiosity for those interested in the history of cinema--very bad cinema.
# 19218  label:  0
# 19256  label:  1
# 19296  label:  1
# 19300  label:  1
# 19400  label:  0
# 19406  label:  0
# 19447  label:  0
# 19478  label:  0
# 19520  label:  0
# 19522  label:  1
# 19530  label:  0
# 19539  label:  1
# 19541  label:  0
# 19583  label:  1
# 19600  label:  1
# 19640  label:  1
# 19656  label:  0
# 19657  label:  0
# 19667  label:  1
# 19705  label:  1
# 19709  label:  0
# 19796  label:  0
# 19802  label:  1
# 19878  label:  1
# 19886  label:  0
# 19937  label:  0
# 19950  label:  0
# 19955  label:  1
# 19971  label:  0
# 19978  label:  0
# 20063  label:  0
# 20065  label:  1
# 20084  label:  1
# 20093  label:  1
# 20109  label:  0
# 20117  label:  0
#  . well, i hate hollywood, but love cinema so i have to watch these cruddy movie in theater.
# 20174  label:  1
# 20185  label:  0
# 20193  label:  0
# 20204  label:  1
# 20210  label:  0
# 20228  label:  1
# 20280  label:  1
# 20341  label:  1
# 20342  label:  0
# 20374  label:  1
# 20387  label:  1
# 20487  label:  0
# 20574  label:  1
# 20584  label:  0
# 20612  label:  0
# 20640  label:  0
# 20652  label:  1
# 20683  label:  0
# 20784  label:  0
# 20796  label:  0
# 20804  label:  0
# 20822  label:  1
#  . but, the cinematography seemed weak.
# 20831  label:  1
#  . sure, the filming and "cinematographic" importance might not be that significan not.
# 20852  label:  0
# 20880  label:  1
# 20892  label:  0
# 20895  label:  0
#  . i have seen many cheaply made independent film but somehow the cinematography and quality of this movie set it apart from anything else i have ever seen.
# 20913  label:  0
# 20947  label:  1
# 20954  label:  1
#  . the illiance of the dialogue cannot be matched anywhere today, especially considering that "realism" has taken over and engulfed contemporary cinema.this film was made at a time when the hayes code restricting content was being ignored and the result is a fresh, self-referential, critical and living cinema that spoke directly to contemporary audience suffering through the depression and the general angst of the age.
#  . i'd recommend watching any film from this period, that is 1930-1935, for a vision of what popular cinema can potentially be.
# 20996  label:  1
# 21035  label:  1
# 21065  label:  0
# 21085  label:  0
# 21129  label:  0
# 21273  label:  1
# 21303  label:  0
# 21334  label:  0
# 21360  label:  0
# 21402  label:  0
#  . so a group of filmmaker decide to pick up where the film left off even though they are warned by person to keep away from the film, as the last person who was interested in the flick turned up dead in the cinema while watching the film.
#  . the cinema scene is done rather nicely too.now, now we know we want gore and nudity when watching this type of flick, but sadly there is no nudity to be found and the gore is pretty standard, if lacking but it is more then decent for such low-budget flick.
# 21471  label:  0
# 21473  label:  1
# 21539  label:  0
# 21549  label:  0
#  . the movie itself is disappointing and only confirming the limited role of french cinema in the world nowadays.
# 21561  label:  0
# 21585  label:  1
# 21620  label:  0
# 21633  label:  1
# 21666  label:  1
# 21669  label:  0
# 21672  label:  0
# 21688  label:  1
# 21744  label:  0
# 21796  label:  0
# 21875  label:  1
#  . of course this is not something that is typically italian but got done quite a lot in the early day of cinema, mostly because they often thought they would be able to get away with it.
# 21900  label:  1
# 21927  label:  0
# 21930  label:  0
# 22079  label:  0
# 22086  label:  1
# 22145  label:  1
# 22182  label:  0
# 22196  label:  1
# 22210  label:  1
#  . once he sets his eye on laurie after she drops off a package to the abandoned house where he lived, he begins to stalk and terrorize her, turning her night of fun into terror as he picks off anyone in his path to get to her.beautiful cinematography and lighting really make this moody horror flick scary... with the long gloomy shot it constantly feels as if you are being stalked by the maniacal serial killer himself.
# 22230  label:  1
# 22243  label:  1
# 22264  label:  1
# 22308  label:  0
# 22322  label:  0
# 22336  label:  0
# 22351  label:  0
# 22361  label:  0
# 22395  label:  1
# 22422  label:  0
# 22496  label:  1
# 22511  label:  0
# 22515  label:  0
# 22613  label:  0
#  . the supporting cast are hardly worth mentioning but it is a shame to see such a great actress as agne moorhead barely getting a look in as ma jame.the best aspect of this uninvolving so-so western is the wonderful cinemascope/colour cinematography by the great joe mcdonald and the excellent music score by the underrated and little known composer leigh harline!
# 22616  label:  1
# 22649  label:  1
#  . as far as indie cinema goes, this may not be perfect from a technical standpoint, but from an artistic one, it is very close.
# 22678  label:  1
# 22707  label:  1
# 22724  label:  0
# 22774  label:  1
# 22783  label:  0
# 22832  label:  0
# 22841  label:  0
# 22852  label:  1
# 22897  label:  0
# 22925  label:  1
# 22978  label:  0
# 22988  label:  0
# 23017  label:  1
# 23066  label:  0
# 23111  label:  0
# 23128  label:  0
# 23222  label:  1
# 23225  label:  1
# 23235  label:  1
# 23243  label:  1
# 23272  label:  1
# 23294  label:  0
#  . it is weighed down by dreadful acting, a genuinely dire script, indifferent cinematography and student-level production value.
#  . totally meaningless, utterly lightweight, poorly put together; this movie is a dreadful embarrassment for uk cinema.
# 23336  label:  1
# 23364  label:  1
# 23380  label:  0
# 23465  label:  0
#  . with no creativity in sight and unmanaged actor just trying to upstage themselves, what originally started as a decent story eventually sunk faster into the cinematic quicksand.
# 23497  label:  1
# 23591  label:  1
# 23639  label:  0
# 23785  label:  0
# 23820  label:  1
# 23875  label:  0
# 23912  label:  0
# 23919  label:  0
# 23937  label:  0
#  . hollywood, and in this case, the italian cinema, treat these guy as hero.
# 23957  label:  1
# 23965  label:  0
#  . i have found a holy grail, a real touchstone of bad cinema.
# 23973  label:  0
# 23978  label:  1
# 24007  label:  0
#  . ),david ander (hero and alias),laura vandervoort (smallville),marsha tomason (lost) and audrina patridge (the hill) ing hollow and boring performances.i have liked some previous movie from director stephen herek (critter and bill and ted's excellent adventure specially) but on this movie,he cannot generate even the minimum level of tension,emotion or entertainment.the character from this movie are not only badly performed,but they are also repulsive.honestly,i wanted all of them to die.the cinematography from this movie is also lame and it seems to have been made by a technical team who makes promotional video for hawaiian hotels.into the blue 2 : the reef is a horrible movie which is better than the original film,but that is the same as nothing,as i previously said.avoid this crappy film at all cost.
# 24058  label:  1
# 24090  label:  0
# 24092  label:  0
# 24182  label:  0
# 24191  label:  1
# 24210  label:  0
# 24213  label:  0
# 24267  label:  0
# 24298  label:  0
# 24347  label:  0
# 24371  label:  1
# 24374  label:  0
# 24414  label:  0
# 24552  label:  0
# 24554  label:  1
# 24564  label:  1
# 24641  label:  1
# 24735  label:  1
# 24745  label:  1
# 24765  label:  0
# 24779  label:  1
# 24814  label:  0
# 24818  label:  1
# 24829  label:  0
# 24834  label:  1
# 24844  label:  0
# 24868  label:  0
# 24894  label:  1

# %% [markdown]
# ### Generate tree relation
#
# Reference : <br>
# https://stackoverflow.com/questions/2358045/how-can-i-implement-a-tree-in-python-are-there-any-built-in-data-structures-in
# http://anytree.readthedocs.io/en/latest/ <br>
# <br>
# There is not sign changed when the top_words=100

# %%
one_gram = load_list("1gram.txt",'\t')
two_gram = load_list("2gram.txt",'\t')
three_gram = load_list("3gram.txt", '\t')
four_gram = load_list("4gram.txt", '\t')
five_gram = load_list("5gram.txt", '\t')

# %%
negated = []
amplifier = []
ind_words = 0
for i in one_gram:
    for j in two_gram:
        split_words = j[0].split()
        after_weight = float(j[1])
        previous_weight = float(i[1])
        for k in range(0, len(split_words)):
            if i[0] == split_words[k]:
                if k == 0:
                    ind_words = 1
                elif k == 1:
                    ind_words = 0
                   
                if np.sign(after_weight)!=np.sign(previous_weight) or np.absolute(after_weight) < np.absolute(previous_weight):
                    negated.append(split_words[ind_words])
                else:
                    amplifier.append(split_words[ind_words])
                print(i[0], i[1],'\t', j[0], j[1])
print()
print('negated')
print(np.unique(negated))
print('amplifier')
print(np.unique(amplifier))

#############################################
# top_words = 1000
# best 0.60 	 at best -1.80

# negated
# ['at']
# amplifier
# []

# %%
negated = []
amplifier = []
ind_words = 0
for i in one_gram:
    for j in three_gram:
        split_words = j[0].split()
        after_weight = float(j[1])
        previous_weight = float(i[1])
        for k in range(0, len(split_words)):
            if i[0] == split_words[k] and (np.absolute(after_weight)>np.absolute(previous_weight) or np.sign(after_weight)!=np.sign(previous_weight)):
                if k == 0:
                    ind_words = 1
                elif k == 1:
                    ind_words = 0
                   
                if np.sign(after_weight)!=np.sign(previous_weight):
                    negated.append(split_words[ind_words])
                else:
                    amplifier.append(split_words[ind_words])
                print(i[0], i[1],'\t', j[0], j[1])
print()
print('negated')
print(np.unique(negated))
print('amplifier')
print(np.unique(amplifier))

# %%
for i in two_gram:
    for j in three_gram:
        after_weight = float(j[1])
        previous_weight = float(i[1])
        if i[0] in j[0]:
            print(i[0], i[1],'\t', j[0], j[1])

# %%
for i in two_gram:
    for j in four_gram:
        after_weight = float(j[1])
        previous_weight = float(i[1])
        if i[0] in j[0]:
            print(i[0], i[1],'\t', j[0], j[1])

# %%
for i in one_gram:
    for j in five_gram:
        after_weight = float(j[1])
        previous_weight = float(i[1])
        if i[0] in j[0] and np.sign(after_weight)!=np.sign(previous_weight):
            print(i[0], i[1],'\t', j[0], j[1])

# %%
parent_index = 0
child_index = 0
parent_node = [Node("") for _ in range(len(three_gram))]
child_node = [Node("") for _ in range(len(five_gram))]

for i in three_gram:
    parent_node[parent_index] = Node(i[0])
    for j in five_gram:
        if i[0] in j[0] and j[1]>i[1]:
            print(i[0], i[1],'\t', j[0], j[1])
            child_node = Node(j[0], parent=parent_node[parent_index])
    parent_index = parent_index + 1

# %%
for i in range(0,len(three_gram)):
    for pre, fill, node in RenderTree(parent_node[i]):
        if parent_node[i].height != 0:
            print("%s%s" % (pre, node.name))

# %%
parent_index = 0
two_index = 0
three_index = 0
four_index = 0
parent_node = [Node("") for _ in range(len(one_gram))]
two_node = [Node("") for _ in range(len(two_gram))]
three_node = [Node("") for _ in range(len(three_gram))]
four_node = [Node("") for _ in range(len(four_gram))]

for one in one_gram:
    parent_node[parent_index] = Node(one[0])
    for two in two_gram:
        if one[0] in two[0]:
            two_node[two_index] = Node(two[0], parent=parent_node[parent_index])
            for three in three_gram:
                if two[0] in three[0]:
                    three_node[three_index] = Node(three[0], parent=two_node[two_index])
                    for four in four_gram:
                        if three[0] in four[0]:
                            four_node[four_index] = Node(four[0], parent=three_node[three_index])
                            four_index = four_index + 1
                            print(one[0], one[1],'\t', two[0], two[1], '\t', three[0], three[1], '\t', four[0], four[1])
                    three_index = three_index + 1
            two_index = two_index + 1
    parent_index = parent_index + 1

# %%
for i in range(0,len(one_gram)):
    for pre, fill, node in RenderTree(parent_node[i]):
        if parent_node[i].height != 0:
            print("%s%s" % (pre, node.name))
